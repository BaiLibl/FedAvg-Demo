# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/"Colab Notebooks"/FedAvg
# !pip install tensorboardX

# %%
# !python baseline_main.py --model=mlp --dataset=mnist --epochs=100 > mlp_mnist.txt
# !python baseline_main.py --model=cnn --dataset=mnist --epochs=100 > cnn_mnist.txt

# !python baseline_main.py --model=mlp --dataset=cifar --epochs=100 > mlp_cifar.txt
# !python baseline_main.py --model=cnn --dataset=cifar --epochs=100 > cnn_cifar.txt

# %%
# !python federated_main.py --model=cnn --dataset=cifar --iid=1 --num_users=50 --epochs=100 > cf_50.txt
# !python federated_main.py --model=cnn --dataset=cifar --iid=1 --num_users=100 --epochs=100 > cf_100.txt
# Out:
# 100% 100/100 [18:45<00:00, 11.25s/it]
# 100% 100/100 [19:22<00:00, 11.63s/it]

# %%
# !python federated_main.py --model=cnn --dataset=cifar --iid=1 --epochs=100 > cnn_cifar_1_100.txt
# !python federated_main.py --model=cnn --dataset=cifar --iid=0 --epochs=100 > cnn_cifar_0_100.txt

# %%
# !python federated_main.py --model=cnn --dataset=cifar --iid=1 --epochs=100 > cnn_cifar_1_100.txt
# !python federated_main.py --model=cnn --dataset=cifar --iid=1 --num_users=50 --epochs=100 > cnn_cifar_1_50.txt

# !python federated_main.py --model=mlp --dataset=cifar --iid=1 --num_users=50 --epochs=100 > mlp_cifar_1_50.txt
# !python federated_main.py --model=mlp --dataset=cifar --iid=1 --num_users=100 --epochs=100 > mlp_cifar_1_100.txt
# Out:
#   0% 0/100 [00:00<?, ?it/s]/content/drive/MyDrive/Colab Notebooks/FedAvg/src/update.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(image), torch.tensor(label)
# 100% 100/100 [35:31<00:00, 21.32s/it]
#   0% 0/100 [00:00<?, ?it/s]/content/drive/MyDrive/Colab Notebooks/FedAvg/src/update.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(image), torch.tensor(label)
# 100% 100/100 [28:23<00:00, 17.04s/it]
# ...
